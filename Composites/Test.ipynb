# %%
from composipy import OrthotropicMaterial, LaminateProperty
from composipy import PlateStructure
import matplotlib

# %%
#Ply Material Properties (MPa and mm)
E1 = 60800
E2 = 58250
v12 = 0.07
G12 = 4550
t = 0.21

# Plate Parameters (mm)
a = 360.
b = 360.
m = 10 # discretization in x direction
n = 10 # discretization in y direction


# Stacking sequence
stacking = [45,-45,0,90,45,-45,0,90,45,-45]
stacking += stacking[::-1] # symmetry

# %%
# Ply material and laminate property objects

ply_1 = OrthotropicMaterial(E1, E2, v12, G12, t)
l1 = LaminateProperty(stacking, ply_1)

# %%
l1
# Out:
# composipy.LaminateProperty
# stacking = [45, -45, 0, 90, 45, -45, 0, 90, 45, -45, -45, 45, 90, 0, -45, 45, 90, 0, -45, 45]

# %%
import composipy
import composipy.optimize

res = composipy.optimize.maximize_buckling_load(a,b,t,E1,E2,v12,G12,Nxx=1)

# %%
res
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: 41.7764326077158
#        x: [ 5.000e-05 -1.000e+00]
#      nit: 2
#      jac: [-1.473e+00  1.264e+01]
#     nfev: 6
#     njev: 2

# %%
res.x
# Out:
# array([ 5.e-05, -1.e+00])

# %%
import itertools
import numpy as np
import math

def calculate_cost(path, angle_matrix):
    cost = 0
    for i in range(len(path) - 1):
        cost += math.cos(angle_matrix[path[i]][path[i+1]])
    cost += math.cos(angle_matrix[path[-1]][path[0]])  # To complete the tour
    return cost

def brute_force_tsp(angle_matrix):
    num_cities = len(angle_matrix)
    all_permutations = itertools.permutations(range(num_cities))
    
    best_path = None
    best_cost = float('inf')
    
    for path in all_permutations:
        current_cost = calculate_cost(path, angle_matrix)
        if current_cost < best_cost:
            best_cost = current_cost
            best_path = path
    
    return best_path, best_cost

# Example usage:
np.random.seed(42)  # Pour la reproductibilité

angle_matrix = np.random.rand(10, 10) * 90  # Example matrix with random angles between 0 and pi/2
angle_matrix = (angle_matrix + angle_matrix.T)/2

best_path, best_cost = brute_force_tsp(angle_matrix)
print("Best path:", best_path)
print("Best cost:", best_cost)
# Out:
# Best path: (0, 8, 1, 9, 6, 5, 7, 3, 4, 2)
# Best cost: -6.48303190678916

# %%
import numpy as np
import random
import math

def calculate_cost(path, angle_matrix):
    cost = 0
    for i in range(len(path) - 1):
        cost += math.cos(angle_matrix[path[i]][path[i+1]])
    cost += math.cos(angle_matrix[path[-1]][path[0]])  # To complete the tour
    return cost

def simulated_annealing(angle_matrix, initial_temp, cooling_rate, stopping_temp):
    num_cities = len(angle_matrix)
    
    # Generate an initial solution
    current_solution = list(range(num_cities))
    random.shuffle(current_solution)
    current_cost = calculate_cost(current_solution, angle_matrix)
    
    best_solution = current_solution.copy()
    best_cost = current_cost
    
    temperature = initial_temp
    
    while temperature > stopping_temp:
        # Create a new solution by swapping two cities
        new_solution = current_solution.copy()
        i, j = random.sample(range(num_cities), 2)
        new_solution[i], new_solution[j] = new_solution[j], new_solution[i]
        
        new_cost = calculate_cost(new_solution, angle_matrix)
        
        # Determine if we should accept the new solution
        if new_cost < current_cost or random.random() < math.exp((current_cost - new_cost) / temperature):
            current_solution = new_solution
            current_cost = new_cost
            
            # Update the best solution found so far
            if new_cost < best_cost:
                best_solution = new_solution
                best_cost = new_cost
        
        # Cool down the temperature
        temperature *= cooling_rate
    
    return best_solution, best_cost

initial_temp = 1000
cooling_rate = 0.99
stopping_temp = 0.00001

best_path, best_cost = simulated_annealing(angle_matrix, initial_temp, cooling_rate, stopping_temp)
print("Best path:", best_path)
print("Best cost:", best_cost)
# Out:
# Best path: [0, 8, 1, 9, 6, 5, 7, 3, 4, 2]
# Best cost: -6.48303190678916

# %%
import numpy as np
import math
import random

class AntColony:
    def __init__(self, angle_matrix, num_ants, num_iterations, decay, alpha=1, beta=1):
        self.angle_matrix = angle_matrix
        self.num_ants = num_ants
        self.num_iterations = num_iterations
        self.decay = decay
        self.alpha = alpha
        self.beta = beta
        self.num_cities = len(angle_matrix)
        self.pheromone = np.ones((self.num_cities, self.num_cities)) / self.num_cities

    def run(self):
        best_path = None
        best_cost = float('inf')
        
        for i in range(self.num_iterations):
            all_paths = self.generate_all_paths()
            self.spread_pheromone(all_paths, self.num_ants)
            best_path, best_cost = self.get_best_path(all_paths, best_path, best_cost)
            print(f'------ Iteration {i} ------')
            print('current best_path :', best_path, 'current best_cost :',best_cost)
            self.pheromone * self.decay
            
        return best_path, best_cost

    def generate_all_paths(self):
        all_paths = []
        for i in range(self.num_ants):
            path = self.generate_path(0)
            all_paths.append((path, self.calculate_cost(path)))
        return all_paths

    def generate_path(self, start):
        path = []
        visited = set()
        visited.add(start)
        prev = start
        
        for _ in range(self.num_cities - 1):
            move = self.pick_move(self.pheromone[prev], self.angle_matrix[prev], visited)
            path.append((prev, move))
            prev = move
            visited.add(move)
            
        path.append((prev, start))
        return path

    def pick_move(self, pheromone, angles, visited):
        pheromone = np.copy(pheromone)
        pheromone[list(visited)] = 0
        
        row = pheromone ** self.alpha * ((1.0 / (angles + 1e-10)) ** self.beta)
        norm_row = row / row.sum()
        move = np_choice(range(self.num_cities), 1, p=norm_row)[0]
        return move

    def calculate_cost(self, path):
        total_cost = 0
        for move in path:
            total_cost += math.cos(self.angle_matrix[move[0]][move[1]])
        return total_cost

    def spread_pheromone(self, all_paths, num_ants):
        sorted_paths = sorted(all_paths, key=lambda x: x[1])
        for path, cost in sorted_paths[:num_ants]:
            for move in path:
                self.pheromone[move] += 1.0 / self.angle_matrix[move[0]][move[1]]

    def get_best_path(self, all_paths, best_path, best_cost):
        for path, cost in all_paths:
            if cost < best_cost:
                best_path = path
                best_cost = cost
        return best_path, best_cost

def np_choice(a, size, p):
    return np.random.choice(a, size=size, p=p)

# Test with a small example matrix
#angle_matrix = np.array([
#    [0, 1, 2, 3],
#    [1, 0, 1, 2],
#    [2, 1, 0, 1],
#    [3, 2, 1, 0]
#])

num_ants = 100
num_iterations = 1000
decay = 0.995
alpha = 0.7
beta = 0.001

ant_colony = AntColony(angle_matrix, num_ants, num_iterations, decay, alpha, beta)
best_path_aco, best_cost_aco = ant_colony.run()

print("Ant Colony Optimization - Best path:", best_path_aco, "Best cost:", best_cost_aco)
# Out:
# ------ Iteration 0 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 1), (1, 8), (8, 9), (9, 3), (3, 0)] current best_cost : -3.9733174762993335
# ------ Iteration 1 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 1), (1, 8), (8, 9), (9, 3), (3, 0)] current best_cost : -3.9733174762993335
# ------ Iteration 2 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 3 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 4 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 5 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 6 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 7 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 8 ------
# current best_path : [(0, 7), (7, 4), (4, 2), (2, 6), (6, 5), (5, 8), (8, 9), (9, 1), (1, 3), (3, 0)] current best_cost : -4.360444734146218
# ------ Iteration 9 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 10 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 11 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 12 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 13 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 14 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 15 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 16 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 17 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 18 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 19 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 20 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 21 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 22 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 23 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 24 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 25 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 26 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 27 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 28 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 29 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 30 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 31 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 32 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 33 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 34 ------
# current best_path : [(0, 6), (6, 5), (5, 1), (1, 8), (8, 9), (9, 2), (2, 4), (4, 3), (3, 7), (7, 0)] current best_cost : -4.643092844882425
# ------ Iteration 35 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 36 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 37 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 38 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 39 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 40 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 41 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 42 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 43 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 44 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 45 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 46 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 47 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 48 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 49 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 50 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 51 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 52 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 53 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 54 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 55 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 56 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 57 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 58 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 59 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 60 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 61 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 62 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 63 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 64 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 65 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 66 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 67 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 68 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 69 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 70 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 71 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 72 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 73 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 74 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 75 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 76 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 77 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 78 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 79 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 80 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 81 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 82 ------
# current best_path : [(0, 8), (8, 9), (9, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 0)] current best_cost : -4.767760233575342
# ------ Iteration 83 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 84 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 85 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 86 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 87 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 88 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 89 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 90 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 91 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 92 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 93 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 94 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 95 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 96 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 97 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 98 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 99 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 100 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 101 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 102 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 103 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 104 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 105 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 106 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 107 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 108 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 109 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 110 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 111 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 112 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 113 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 114 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 115 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 116 ------
# current best_path : [(0, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 3), (3, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -4.952419951024885
# ------ Iteration 117 ------
# current best_path : [(0, 3), (3, 6), (6, 5), (5, 7), (7, 1), (1, 8), (8, 9), (9, 4), (4, 2), (2, 0)] current best_cost : -5.005342542951073
# ------ Iteration 118 ------
# current best_path : [(0, 3), (3, 6), (6, 5), (5, 7), (7, 1), (1, 8), (8, 9), (9, 4), (4, 2), (2, 0)] current best_cost : -5.005342542951073
# ------ Iteration 119 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 120 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 121 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 122 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 123 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 124 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 125 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 126 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 127 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 128 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 129 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 130 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 131 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 132 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 133 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 134 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 135 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 136 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 137 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 138 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 139 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 140 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 141 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 142 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 143 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 144 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 145 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 146 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 147 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 148 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 149 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 150 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 151 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 152 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 153 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 154 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 155 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 156 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 157 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 158 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 159 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 160 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 161 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 162 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 163 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 164 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 165 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 166 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 167 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 168 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 169 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 170 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 171 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 172 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 173 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 174 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 175 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 176 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 177 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 178 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 179 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 180 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 181 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 182 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 183 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 184 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 185 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 186 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 187 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 188 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 189 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 190 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 191 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 192 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 193 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 194 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 195 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 196 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 197 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 198 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 199 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 200 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 201 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 202 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 203 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 204 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 205 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 206 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 207 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 208 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 209 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 210 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 211 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 212 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 213 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 214 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 215 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 216 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 217 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 218 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 219 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 220 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 221 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 222 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 223 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 224 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 225 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 226 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 227 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 228 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 229 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 230 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 231 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 232 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 233 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 234 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 235 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 236 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 237 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 238 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 239 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 240 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 241 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 242 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 243 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 244 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 245 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 246 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 247 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 248 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 249 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 250 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 251 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 252 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 253 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 254 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 255 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 256 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 257 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 258 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 259 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 260 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 261 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 262 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 263 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 264 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 265 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 266 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 267 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 268 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 269 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 270 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 271 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 272 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 273 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 274 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 275 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 276 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 277 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 278 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 279 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 280 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 281 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 282 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 283 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 284 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 285 ------
# current best_path : [(0, 3), (3, 7), (7, 5), (5, 6), (6, 2), (2, 4), (4, 1), (1, 9), (9, 8), (8, 0)] current best_cost : -5.963320377444966
# ------ Iteration 286 ------
# ...
# ------ Iteration 906 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 907 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 908 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 909 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 910 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 911 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 912 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 913 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 914 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 915 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 916 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 917 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 918 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 919 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 920 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 921 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 922 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 923 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 924 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 925 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 926 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 927 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 928 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 929 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 930 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 931 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 932 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 933 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 934 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 935 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 936 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 937 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 938 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 939 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 940 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 941 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 942 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 943 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 944 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 945 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 946 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 947 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 948 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 949 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 950 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 951 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 952 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 953 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 954 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 955 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 956 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 957 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 958 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 959 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 960 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 961 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 962 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 963 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 964 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 965 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 966 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 967 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 968 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 969 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 970 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 971 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 972 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 973 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 974 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 975 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 976 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 977 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 978 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 979 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 980 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 981 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 982 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 983 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 984 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 985 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 986 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 987 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 988 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 989 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 990 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 991 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 992 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 993 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 994 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 995 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 996 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 997 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 998 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# ------ Iteration 999 ------
# current best_path : [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] current best_cost : -5.980847883228677
# Ant Colony Optimization - Best path: [(0, 8), (8, 9), (9, 1), (1, 3), (3, 4), (4, 2), (2, 6), (6, 5), (5, 7), (7, 0)] Best cost: -5.980847883228677

# %%
import subprocess



def launch_calcul():
    l1 = subprocess.check_output('wsl -d smeca /opt/sm/bin/as_run /mnt/c/Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/export')
    return(l1)

def write_in_aster(chemin):
    filename = 'C://Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/RunCase_11_Stage_1.comm'
    with open(filename, 'r') as file:
            lines = file.readlines()

    to_bewritten = f'''_F(EPAIS=5.0, 
                                   MATER={liste_mat[chemin[0]]}, 
                                   ORIENTATION={0}),'''
    for i in range(int(len(chemin))-1):
        to_bewritten += f'''\n                                _F(EPAIS=5.0, 
                                   MATER={liste_mat[chemin[i]]}, 
                                   ORIENTATION={antisymmetric_matrix[chemin[i]][chemin[i+1]]}),'''

    for k, line in enumerate(lines):
        if 'clt140 = ' in line:
            index = k
            break
    lines[index] = f'''clt140 = DEFI_COMPOSITE(identifier='5:1', 
                        COUCHE=({to_bewritten}))\n'''

    with open(filename, 'w') as file:
        file.writelines(lines)
    
    with open(filename, 'w') as file:
        file.writelines(lines)
    for i, line in enumerate(lines):
            if 'N = ' in line:
                lines[i] = f'N = {len(chemin)}\n'
                break

    with open(filename, 'w') as file:
        file.writelines(lines)

# %%
def remove_section():
        file_path = 'C://Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/RunCase_11_Stage_1.comm'
        with open(file_path, 'r') as file:
            lines = file.readlines()

        start_keyword = 'clt140 = '
        end_keyword = 'fieldmat = '
        new_lines = []
        inside_section = False

        for line in lines:
            if start_keyword in line:
                new_lines.append(line)
                inside_section = True
            elif end_keyword in line and inside_section:
                inside_section = False
                new_lines.append(line)
            elif not inside_section:
                new_lines.append(line)

        with open(file_path, 'w') as file:
            file.writelines(new_lines)

# %%
def read_defo():
        file_path = 'C://Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/defo'
        defo_values = []
        start_reading = False
        with open(file_path, 'r') as file:
            for line in file:
                line = line.strip()
                if "EPXX" in line:
                    start_reading = True

                if start_reading:
                    if '=====>' in line:
                        break
                    try:
                        defo = line.split("|")
                        if len(defo) <= 5:
                            break
                        else:
                            defo = float(defo[4])
                            defo_values.append(defo)
                    except ValueError:
                        continue
        return defo_values

def read_cons():
        file_path = 'C://Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/cons'
        defo_values = []
        start_reading = False
        with open(file_path, 'r') as file:
            for line in file:
                line = line.strip()
                if "SIXX" in line:
                    start_reading = True

                if start_reading:
                    if '=====>' in line:
                        break
                    try:
                        defo = line.split("|")
                        if len(defo) <= 5:
                            break
                        else:
                            defo = float(defo[4])
                            defo_values.append(defo)
                    except ValueError:
                        continue
        return defo_values

# %%
liste_mat = ['bois1', 'bois2', 'bois1', 'bois2']
import numpy as np

# Créer une matrice 5x5 avec des éléments aléatoires entre -90 et 90
matrix = np.random.randint(-90, 91, size=(4, 4))

# Rendre la matrice antisymétrique en soustrayant sa transpose et en divisant par 2
antisymmetric_matrix = (matrix - matrix.T) / 2

# Mettre les éléments diagonaux à zéro
np.fill_diagonal(antisymmetric_matrix, 0)

# %%
import itertools
import numpy as np
import math

def calculate_cost(path):
    remove_section()
    write_in_aster(path)
    
    launch_calcul()
    defo = max(np.abs(read_defo()))
    cons = max(np.abs(read_cons()))
    return(cons/defo)

def brute_force_tsp(angle_matrix):
    num_cities = len(angle_matrix)
    all_permutations = itertools.permutations(range(num_cities))
    
    best_path = None
    best_cost = float('inf')
    
    for path in all_permutations:
        current_cost = calculate_cost(path)
        if current_cost < best_cost:
            best_cost = current_cost
            best_path = path
        print('chemin testé :' , path, 'cout actuel :' , current_cost)
    return best_path, best_cost


best_path, best_cost = brute_force_tsp(antisymmetric_matrix)
print("Best path:", best_path)
print("Best cost:", best_cost)
# Out:
# chemin testé : (0, 1, 2, 3) cout actuel : 5069.585870455439
# chemin testé : (0, 1, 3, 2) cout actuel : 7704.746535874708
# chemin testé : (0, 2, 1, 3) cout actuel : 8769.392627620235
# chemin testé : (0, 2, 3, 1) cout actuel : 9478.29209672251
# chemin testé : (0, 3, 1, 2) cout actuel : 8595.303140746737
# chemin testé : (0, 3, 2, 1) cout actuel : 10229.778885842972
# chemin testé : (1, 0, 2, 3) cout actuel : 7308.010642715174
# chemin testé : (1, 0, 3, 2) cout actuel : 5955.980180248793
# chemin testé : (1, 2, 0, 3) cout actuel : 6874.9785720238215
# chemin testé : (1, 2, 3, 0) cout actuel : 6518.32903088356
# chemin testé : (1, 3, 0, 2) cout actuel : 10098.003374489212
# chemin testé : (1, 3, 2, 0) cout actuel : 11258.74229815473
# chemin testé : (2, 0, 1, 3) cout actuel : 11023.982385411435
# chemin testé : (2, 0, 3, 1) cout actuel : 8751.47841401925
# chemin testé : (2, 1, 0, 3) cout actuel : 9437.88467136821
# chemin testé : (2, 1, 3, 0) cout actuel : 6600.118943525421
# chemin testé : (2, 3, 0, 1) cout actuel : 11632.60127211091
# chemin testé : (2, 3, 1, 0) cout actuel : 11632.314168433411
# chemin testé : (3, 0, 1, 2) cout actuel : 8848.87990433279
# chemin testé : (3, 0, 2, 1) cout actuel : 8059.865337297397
# chemin testé : (3, 1, 0, 2) cout actuel : 10834.334082680653
# chemin testé : (3, 1, 2, 0) cout actuel : 9665.763775866231
# chemin testé : (3, 2, 0, 1) cout actuel : 8753.632539881342
# chemin testé : (3, 2, 1, 0) cout actuel : 8365.785306850561
# Best path: (0, 1, 2, 3)
# Best cost: 5069.585870455439

# %%
10*9*8*7*6*5*4*3*2*13/60/60
# Out:
# 13104.0

# %%
import random
def simulated_annealing(angle_matrix, initial_temp, cooling_rate, stopping_temp):
    num_cities = len(angle_matrix)
    
    # Generate an initial solution
    current_solution = list(range(num_cities))
    random.shuffle(current_solution)
    current_cost = calculate_cost(current_solution)
    
    best_solution = current_solution.copy()
    best_cost = current_cost
    
    temperature = initial_temp
    
    while temperature > stopping_temp:
        # Create a new solution by swapping two cities
        new_solution = current_solution.copy()
        i, j = random.sample(range(num_cities), 2)
        new_solution[i], new_solution[j] = new_solution[j], new_solution[i]
        
        new_cost = calculate_cost(new_solution)
        
        # Determine if we should accept the new solution
        if new_cost < current_cost or random.random() < math.exp((current_cost - new_cost) / temperature):
            current_solution = new_solution
            current_cost = new_cost
            
            # Update the best solution found so far
            if new_cost < best_cost:
                best_solution = new_solution
                best_cost = new_cost
        
        # Cool down the temperature
        temperature *= cooling_rate
    
    return best_solution, best_cost

initial_temp = 1000
cooling_rate = 0.99
stopping_temp = 0.00001

best_path, best_cost = simulated_annealing(antisymmetric_matrix, initial_temp, cooling_rate, stopping_temp)
print("Best path:", best_path)
print("Best cost:", best_cost)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 42
#      39 cooling_rate = 0.99
#      40 stopping_temp = 0.00001
# ---> 42 best_path, best_cost = simulated_annealing(antisymmetric_matrix, initial_temp, cooling_rate, stopping_temp)
#      43 print("Best path:", best_path)
#      44 print("Best cost:", best_cost)
#
# Cell In[10], line 21, in simulated_annealing(angle_matrix, initial_temp, cooling_rate, stopping_temp)
#      18 i, j = random.sample(range(num_cities), 2)
#      19 new_solution[i], new_solution[j] = new_solution[j], new_solution[i]
# ---> 21 new_cost = calculate_cost(new_solution)
#      23 # Determine if we should accept the new solution
#      24 if new_cost < current_cost or random.random() < math.exp((current_cost - new_cost) / temperature):
#
# Cell In[7], line 9, in calculate_cost(path)
#       6 remove_section()
#       7 write_in_aster(path)
# ----> 9 launch_calcul()
#      10 defo = max(np.abs(read_defo()))
#      11 cons = max(np.abs(read_cons()))
#
# Cell In[1], line 6, in launch_calcul()
#       5 def launch_calcul():
# ----> 6     l1 = subprocess.check_output('wsl -d smeca /opt/sm/bin/as_run /mnt/c/Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/export')
#       7     return(l1)
#
# File c:\Users\TOUGERON\AppData\Local\miniconda3\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File c:\Users\TOUGERON\AppData\Local\miniconda3\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Users\TOUGERON\AppData\Local\miniconda3\Lib\subprocess.py:1196, in Popen.communicate(self, input, timeout)
#    1194     self._stdin_write(input)
#    1195 elif self.stdout:
# -> 1196     stdout = self.stdout.read()
#    1197     self.stdout.close()
#    1198 elif self.stderr:
#
# KeyboardInterrupt:

# %%
liste_mat = ['bois1', 'bois2', 'bois1', 'bois2','bois1','bois2','bois1','bois2', 'bois1', 'bois2']
import numpy as np

# Créer une matrice 5x5 avec des éléments aléatoires entre -90 et 90
matrix = np.random.randint(-90, 91, size=(10, 10))

# Rendre la matrice antisymétrique en soustrayant sa transpose et en divisant par 2
antisymmetric_matrix = (matrix - matrix.T) / 2

# Mettre les éléments diagonaux à zéro
np.fill_diagonal(antisymmetric_matrix, 0)

# %%
import numpy as np
import math
import itertools

# Fonction de calcul du coût (à adapter selon vos besoins)
def calculate_cost(path):
    remove_section()
    write_in_aster(path)
    
    launch_calcul()
    defo = max(np.abs(read_defo()))
    cons = max(np.abs(read_cons()))
    return -cons / defo

# Algorithme des fourmis pour le TSP
def ant_colony_tsp(angle_matrix, num_ants, num_iterations, alpha, beta, evaporation_rate):
    num_cities = len(angle_matrix)
    
    # Initialiser les phéromones
    pheromones = np.ones((num_cities, num_cities))
    best_path = None
    best_cost = float('inf')
    
    for iteration in range(num_iterations):
        all_paths = []
        all_costs = []
        
        for ant in range(num_ants):
            path = [np.random.randint(num_cities)]
            while len(path) < num_cities:
                current_city = path[-1]
                probabilities = []
                for next_city in range(num_cities):
                    if next_city not in path:
                        tau = pheromones[current_city, next_city] ** alpha
                        eta = (1 / angle_matrix[current_city, next_city]) ** beta if angle_matrix[current_city, next_city] != 0 else 1
                        probabilities.append(tau * eta)
                    else:
                        probabilities.append(0)
                
                probabilities = np.array(probabilities)
                probabilities = probabilities / probabilities.sum()
                next_city = np.random.choice(range(num_cities), p=probabilities)
                path.append(next_city)
            
            current_cost = calculate_cost(path)
            all_paths.append(path)
            all_costs.append(current_cost)
            
            if current_cost < best_cost:
                best_cost = current_cost
                best_path = path
            
            print(f'Ant {ant} path: {path}, cost: {current_cost}')
        
        # Mise à jour des phéromones
        for i in range(num_cities):
            for j in range(num_cities):
                pheromones[i, j] *= (1 - evaporation_rate)
                
        for path, cost in zip(all_paths, all_costs):
            for i in range(len(path) - 1):
                pheromones[path[i], path[i + 1]] += 1 / cost
            pheromones[path[-1], path[0]] += 1 / cost  # pour rendre le chemin circulaire
    
    return best_path, best_cost

# Paramètres
num_ants = 10
num_iterations = 10
alpha = 1.0  # Importance de la trace de phéromone
beta = 2.0   # Importance de l'heuristique
evaporation_rate = 0.5

# Création de la matrice angle_matrix
angle_matrix = antisymmetric_matrix

# Appel de l'algorithme des fourmis
best_path, best_cost = ant_colony_tsp(angle_matrix, num_ants, num_iterations, alpha, beta, evaporation_rate)
print("Best path:", best_path)
print("Best cost:", best_cost)
# Out:
# Ant 0 path: [3, 7, 9, 5, 8, 1, 2, 0, 6, 4], cost: -9786.23458845515
# Ant 1 path: [2, 8, 5, 9, 7, 1, 6, 3, 4, 0], cost: -10439.4621270467
# Ant 2 path: [0, 3, 7, 9, 5, 6, 1, 8, 4, 2], cost: -8413.656946831856
# Ant 3 path: [2, 3, 7, 9, 5, 6, 1, 8, 4, 0], cost: -9867.1241709099
# Ant 4 path: [7, 3, 4, 9, 5, 8, 1, 6, 0, 2], cost: -10742.754540990689
# Ant 5 path: [5, 9, 4, 7, 3, 6, 8, 1, 2, 0], cost: -10271.083026890632
# Ant 6 path: [1, 7, 3, 0, 2, 6, 8, 5, 9, 4], cost: -10740.807070191799
# Ant 7 path: [7, 3, 6, 5, 9, 4, 8, 1, 2, 0], cost: -10339.675220151365
# Ant 8 path: [4, 6, 0, 2, 5, 9, 3, 7, 1, 8], cost: -10828.899004462342
# Ant 9 path: [8, 5, 9, 0, 3, 7, 1, 2, 6, 4], cost: -7447.883614998058
# Ant 0 path: [3, 7, 4, 9, 5, 6, 8, 0, 2, 1], cost: -8614.89935638716
# Ant 1 path: [8, 1, 6, 0, 3, 7, 9, 5, 2, 4], cost: -10559.720712533199
# Ant 2 path: [7, 0, 2, 9, 5, 8, 1, 4, 3, 6], cost: -10005.34464220605
# Ant 3 path: [9, 5, 8, 6, 7, 3, 4, 0, 2, 1], cost: -9071.028452465605
# Ant 4 path: [6, 5, 9, 3, 7, 0, 4, 8, 1, 2], cost: -10136.32943515311
# Ant 5 path: [9, 5, 8, 0, 3, 7, 4, 6, 1, 2], cost: -9981.554736036313
# Ant 6 path: [3, 7, 9, 5, 8, 1, 6, 2, 0, 4], cost: -10409.820310132953
# Ant 7 path: [6, 8, 1, 2, 7, 3, 4, 9, 5, 0], cost: -10216.718893506524
# Ant 8 path: [1, 8, 5, 9, 3, 7, 4, 6, 0, 2], cost: -10693.237068386705
# Ant 9 path: [5, 9, 3, 7, 6, 8, 1, 2, 0, 4], cost: -10758.284682454128
# Ant 0 path: [0, 3, 7, 4, 9, 5, 8, 1, 2, 6], cost: -10157.781760009413
# Ant 1 path: [2, 0, 7, 3, 4, 9, 5, 8, 1, 6], cost: -12145.804132409365
# Ant 2 path: [5, 9, 3, 7, 4, 8, 1, 6, 0, 2], cost: -10743.181845469753
# Ant 3 path: [7, 3, 9, 5, 6, 8, 1, 2, 0, 4], cost: -11365.388421341353
# Ant 4 path: [7, 3, 0, 9, 5, 8, 1, 4, 2, 6], cost: -8260.94605799481
# Ant 5 path: [6, 5, 9, 7, 3, 0, 4, 1, 8, 2], cost: -9198.806725400593
# Ant 6 path: [4, 3, 7, 0, 6, 8, 5, 9, 1, 2], cost: -8614.529336534306
# Ant 7 path: [3, 7, 4, 9, 5, 8, 1, 6, 2, 0], cost: -9180.067144462508
# Ant 8 path: [6, 5, 9, 7, 3, 2, 0, 4, 1, 8], cost: -8389.9199339612
# Ant 9 path: [1, 9, 4, 3, 7, 6, 0, 2, 5, 8], cost: -11508.620429460007
# Ant 0 path: [9, 5, 8, 6, 7, 3, 0, 2, 1, 4], cost: -6531.429137794731
# Ant 1 path: [4, 8, 6, 5, 9, 3, 7, 2, 1, 0], cost: -7059.989448473266
# Ant 2 path: [6, 7, 3, 9, 5, 8, 1, 2, 0, 4], cost: -10566.46286695199
# Ant 3 path: [9, 5, 8, 6, 1, 4, 3, 7, 2, 0], cost: -11533.766385953755
# Ant 4 path: [6, 2, 7, 3, 9, 5, 8, 1, 0, 4], cost: -8261.70259188361
# Ant 5 path: [4, 5, 9, 3, 7, 0, 2, 8, 6, 1], cost: -8613.485149041484
# Ant 6 path: [8, 5, 9, 0, 6, 2, 4, 7, 3, 1], cost: -9633.93961297827
# Ant 7 path: [1, 8, 5, 9, 3, 7, 0, 6, 4, 2], cost: -8379.222875532958
# Ant 8 path: [3, 9, 5, 6, 0, 7, 2, 1, 8, 4], cost: -8379.79284593645
# Ant 9 path: [6, 5, 9, 3, 7, 0, 4, 8, 1, 2], cost: -10136.32943515311
# Ant 0 path: [3, 0, 4, 7, 6, 5, 8, 1, 9, 2], cost: -9292.837741076288
# Ant 1 path: [7, 3, 9, 5, 8, 6, 4, 0, 2, 1], cost: -10178.281498154061
# Ant 2 path: [0, 7, 6, 8, 5, 9, 3, 4, 1, 2], cost: -8607.572141158278
# Ant 3 path: [0, 7, 9, 5, 8, 4, 3, 2, 1, 6], cost: -8713.233115581292
# Ant 4 path: [8, 5, 9, 3, 0, 6, 1, 4, 7, 2], cost: -12099.597624980137
# Ant 5 path: [6, 3, 7, 5, 9, 4, 0, 2, 8, 1], cost: -11378.11776434367
# Ant 6 path: [2, 1, 8, 5, 9, 7, 3, 0, 6, 4], cost: -9943.291558497689
# Ant 7 path: [4, 8, 5, 9, 3, 7, 0, 6, 1, 2], cost: -11610.688029874995
# Ant 8 path: [2, 7, 3, 9, 5, 8, 1, 6, 0, 4], cost: -10340.899449164219
# Ant 9 path: [1, 6, 2, 5, 9, 8, 4, 3, 7, 0], cost: -10738.833080175986
# Ant 0 path: [2, 7, 3, 9, 5, 8, 1, 4, 0, 6], cost: -9741.368299992946
# Ant 1 path: [3, 7, 0, 2, 5, 9, 4, 1, 6, 8], cost: -11033.559705623027
# Ant 2 path: [0, 2, 4, 3, 7, 5, 9, 1, 8, 6], cost: -11629.333763082768
# Ant 3 path: [8, 5, 9, 3, 0, 2, 6, 7, 4, 1], cost: -5786.3911998010635
# Ant 4 path: [0, 3, 7, 9, 5, 8, 1, 2, 6, 4], cost: -9063.416402000736
# Ant 5 path: [4, 3, 7, 0, 6, 1, 8, 5, 9, 2], cost: -9967.757331534578
# Ant 6 path: [7, 3, 9, 5, 8, 1, 0, 4, 6, 2], cost: -6938.105880423132
# Ant 7 path: [8, 5, 9, 3, 2, 1, 7, 0, 6, 4], cost: -9075.502241068
# Ant 8 path: [7, 3, 4, 9, 5, 8, 6, 0, 2, 1], cost: -10735.750866653356
# Ant 9 path: [5, 8, 6, 1, 4, 7, 3, 0, 9, 2], cost: -10662.579694439202
# Ant 0 path: [2, 9, 5, 8, 6, 7, 3, 0, 4, 1], cost: -6307.096091189434
# Ant 1 path: [2, 5, 9, 3, 7, 4, 1, 8, 6, 0], cost: -10823.6084000968
# Ant 2 path: [3, 7, 4, 6, 5, 9, 1, 8, 2, 0], cost: -9608.711514940504
# Ant 3 path: [4, 9, 5, 2, 0, 7, 3, 8, 1, 6], cost: -11983.384770119192
# Ant 4 path: [8, 5, 9, 7, 3, 4, 1, 2, 0, 6], cost: -10665.03562990345
# Ant 5 path: [1, 6, 8, 5, 9, 2, 0, 7, 3, 4], cost: -10741.82591027057
# Ant 6 path: [2, 5, 9, 4, 3, 7, 0, 6, 1, 8], cost: -12266.821964404522
# Ant 7 path: [2, 9, 5, 8, 6, 7, 3, 0, 4, 1], cost: -6307.096091189434
# Ant 8 path: [2, 1, 8, 5, 9, 4, 7, 3, 0, 6], cost: -9026.038071966357
# Ant 9 path: [4, 6, 5, 9, 3, 7, 0, 2, 1, 8], cost: -10836.940818702165
# Ant 0 path: [6, 8, 5, 9, 3, 7, 4, 0, 2, 1], cost: -9270.194614267913
# Ant 1 path: [7, 3, 9, 5, 8, 1, 2, 0, 6, 4], cost: -10693.237885153794
# Ant 2 path: [1, 8, 5, 9, 3, 7, 4, 0, 2, 6], cost: -9357.981674306775
# Ant 3 path: [3, 9, 5, 8, 1, 2, 6, 7, 4, 0], cost: -9822.889752779625
# Ant 4 path: [7, 3, 9, 5, 8, 1, 2, 0, 6, 4], cost: -10693.237885153794
# Ant 5 path: [9, 3, 7, 4, 6, 8, 1, 5, 2, 0], cost: -10123.603317529989
# Ant 6 path: [4, 6, 7, 3, 9, 5, 8, 1, 2, 0], cost: -11616.47383828915
# Ant 7 path: [7, 3, 4, 0, 6, 1, 8, 5, 9, 2], cost: -12264.507594129354
# Ant 8 path: [7, 9, 5, 8, 1, 2, 0, 6, 4, 3], cost: -10155.38251573745
# Ant 9 path: [0, 4, 8, 5, 9, 7, 3, 1, 6, 2], cost: -7115.631085036281
# Ant 0 path: [9, 5, 6, 8, 1, 3, 7, 4, 0, 2], cost: -11262.325749229685
# Ant 1 path: [8, 5, 9, 4, 6, 7, 3, 0, 2, 1], cost: -6565.863335687199
# Ant 2 path: [7, 3, 0, 6, 5, 9, 4, 2, 8, 1], cost: -10102.83409745823
# Ant 3 path: [3, 9, 5, 8, 6, 1, 4, 0, 7, 2], cost: -11780.378749845273
# Ant 4 path: [1, 7, 3, 9, 5, 8, 6, 0, 2, 4], cost: -9937.297126430347
# Ant 5 path: [6, 7, 3, 9, 5, 8, 1, 0, 2, 4], cost: -6780.292066164304
# Ant 6 path: [0, 9, 5, 8, 6, 7, 3, 2, 1, 4], cost: -8145.301320979841
# Ant 7 path: [2, 0, 6, 5, 9, 3, 7, 4, 8, 1], cost: -11701.545897886941
# Ant 8 path: [5, 9, 3, 7, 2, 6, 1, 8, 4, 0], cost: -9204.534942649505
# Ant 9 path: [2, 0, 3, 9, 5, 8, 1, 6, 7, 4], cost: -11032.963088347093
# Ant 0 path: [9, 5, 8, 6, 1, 3, 7, 2, 0, 4], cost: -11423.934134282026
# Ant 1 path: [5, 9, 3, 0, 1, 8, 4, 7, 6, 2], cost: -7433.262047427351
# Ant 2 path: [2, 5, 9, 4, 3, 7, 6, 0, 1, 8], cost: -9376.989509095545
# Ant 3 path: [6, 7, 3, 9, 5, 8, 1, 2, 0, 4], cost: -10566.46286695199
# Ant 4 path: [2, 3, 7, 9, 5, 6, 0, 4, 8, 1], cost: -10863.809258629986
# Ant 5 path: [4, 3, 7, 6, 5, 9, 2, 0, 1, 8], cost: -9075.067040792243
# Ant 6 path: [5, 9, 3, 7, 6, 1, 2, 0, 4, 8], cost: -8940.772010146655
# Ant 7 path: [3, 7, 0, 2, 5, 9, 4, 1, 8, 6], cost: -11283.223687372221
# Ant 8 path: [5, 8, 9, 7, 2, 0, 3, 4, 1, 6], cost: -9811.517489495967
# Ant 9 path: [2, 0, 7, 3, 4, 5, 9, 1, 8, 6], cost: -11972.982860965032
# Best path: [2, 5, 9, 4, 3, 7, 0, 6, 1, 8]
# Best cost: -12266.821964404522

# %%
for i in range (len(best_path)):
    print(liste_mat[best_path[i]])
# Out:
# bois1
# bois2
# bois2
# bois1
# bois2
# bois2
# bois1
# bois1
# bois2
# bois1

# %%
def write_in_aster(chemin):
    filename = 'C://Users/TOUGERON/Documents/PRO/SMECA/Test_plaque_trou/Plate_Files/RunCase_11/Result-Stage_1/RunCase_11_Stage_1.comm'
    with open(filename, 'r') as file:
            lines = file.readlines()

    to_bewritten = f'''_F(EPAIS=5.0, 
                                   MATER= bois1, 
                                   ORIENTATION={chemin[0]}),'''
    for i in range(int(len(chemin))-1):
        if i%2==0:
            to_bewritten += f'''\n                                _F(EPAIS=5.0, 
                                    MATER=bois1, 
                                    ORIENTATION={chemin[i]}),'''
        else :
            to_bewritten += f'''\n                                _F(EPAIS=5.0, 
                                    MATER=bois2, 
                                    ORIENTATION={chemin[i]}),''' 

    for k, line in enumerate(lines):
        if 'clt140 = ' in line:
            index = k
            break
    lines[index] = f'''clt140 = DEFI_COMPOSITE(identifier='5:1', 
                        COUCHE=({to_bewritten}))\n'''

    with open(filename, 'w') as file:
        file.writelines(lines)
    for i, line in enumerate(lines):
            if 'N = ' in line:
                lines[i] = f'N = {len(chemin)}\n'
                break

    with open(filename, 'w') as file:
        file.writelines(lines)

# %%
import random
from deap import base, creator, tools, algorithms

# Définir la fonction de calcul de rigidité
def calculate_rigidity(configuration):
    remove_section()
    write_in_aster(configuration)
    
    launch_calcul()
    defo = max(np.abs(read_defo()))
    cons = max(np.abs(read_cons()))
    res = cons / defo
    print(res)
    return res,

# Configuration GA
N_max = 20  # Nombre maximal de plis
orientations = [0, 45, 90, -45]

creator.create("FitnessMax", base.Fitness, weights=(1.0,))
creator.create("Individual", list, fitness=creator.FitnessMax)

def init_individual():
    n_plies = random.randint(3, N_max)  # S'assurer qu'il y a au moins 1 pli
    return creator.Individual([random.choice(orientations) for _ in range(n_plies)])

toolbox = base.Toolbox()
toolbox.register("individual", init_individual)
toolbox.register("population", tools.initRepeat, list, toolbox.individual)

toolbox.register("evaluate", calculate_rigidity)

def cx_custom(ind1, ind2):
    if len(ind1) > 1 and len(ind2) > 1:
        return tools.cxTwoPoint(ind1, ind2)
    else:
        return ind1, ind2

def mut_individual(individual):
    if len(individual) > 1:
        index = random.randrange(len(individual))
        individual[index] = random.choice(orientations)
    else:
        # Si l'individu n'a qu'un pli, il faut simplement changer son orientation
        individual[0] = random.choice(orientations)
    return individual,

toolbox.register("mate", cx_custom)
toolbox.register("mutate", mut_individual)
toolbox.register("select", tools.selTournament, tournsize=3)

# Paramètres GA
population = toolbox.population(n=10)
ngen = 10
cxpb = 0.5
mutpb = 0.2

# Exécuter l'algorithme génétique
result, log = algorithms.eaSimple(population, toolbox, cxpb, mutpb, ngen, verbose=False)

# Meilleure solution trouvée
best_individual = tools.selBest(population, k=1)[0]
print("Meilleure configuration de plis:", best_individual)
print("Rigidité maximale:", calculate_rigidity(best_individual)[0])
# Out:
# 3452.49945513882
# 8672.103824715607
# 5330.879744655067
# 4452.29140090506
# 9058.486938920172
# 6901.037293583345
# 9076.6822090376
# 1625.377190949856
# 2615.2613073769057
# 8276.103249742811
# 8310.389299365224
# 5261.465229885726
# 9058.486938920172
# 9016.465084563406
# 5440.501603100427
# 5273.999465416351
# 9145.348164920953
# 8735.12975329279
# 9235.198141190947
# 8904.772271620628
# 9145.348164920953
# 9076.6822090376
# 8895.914044779784
# 9784.145468491839
# 9055.992140853989
# 9145.348164920953
# 9145.348164920953
# 9068.074682501243
# 9442.870868262866
# 9145.348164920953
# 9466.548875929582
# 9145.348164920953
# 9442.870868262866
# 9145.348164920953
# 9442.870868262866
# 9374.858380912598
# 9386.450883425254
# 9145.348164920953
# 8580.141291718453
# 9794.083858501746
# 9442.870868262866
# 9112.545749106734
# 9794.083858501746
# 9442.870868262866
# 9442.870868262866
# 9442.870868262866
# 9794.083858501746
# 9442.870868262866
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9442.870868262866
# 9442.870868262866
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 5598.091874353341
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# 9794.083858501746
# Meilleure configuration de plis: [-45, 90, 0, -45, 45, 45, 0, -45, 45, -45, 90, 90, 0, 45]
# 9794.083858501746
# Rigidité maximale: 9794.083858501746
